# %% [markdown]
# <a href="https://colab.research.google.com/github/Luoxiaowanzi/IS-4487-Guide/blob/main/My%20completed%20labs/lab_01_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > ### Note on Labs and Assigments:
# >
# > Throughout this lab, you will see **🔧 Try It Yourself** sections. Some labs may also have a final 🔧 **Reflection** section
# >
# > ✅ You are expected to:
# > - Complete each **"🔧 Try It Yourself”** section by writing and running your own code or answering the prompted questions in a markdown or python cell below the section.
# > 🔧 Look for the **wrench emoji** 🔧 — it highlights where you're expected to take action!
# > - Some labs ask for your **comments/Markdown** or have a **Reflection** section at the end of the lab; answer those in your own words (not AI generated answers). This is your opportunity to summarize what you learned and connect the concepts.
# >
# >
# > These sections with a wrench are graded and are not optional.
# >
# > ---

# %% [markdown]
# # **IS 4487 LAB 1 - PYTHON INTRO**
#
# ## Outline
#
# - Create and format cells in a notebook
# - Create basic variables in Python
#
# <a href="https://colab.research.google.com/github/vandanara/UofUtah_IS4487/blob/main/Labs/lab_01_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# If you have any questions about Colab, you can read more here:  https://research.google.com/colaboratory/faq.html

# %% [markdown]
# ## **Part 1: Markdown**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 1**

# %% [markdown]
# 1. Add a Markdown cell below this cell and write (with bullet points for major and food):
#
# - A heading.
# - Your major
# - Your favorite food

# %% [markdown]
# # Hi, this is Linlin
# My majors are Accounting and Finance.
#
# My favorite food is food that made by my family.

# %% [markdown]
# ## **Part 2: Arithmetic**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 2**

# %% [markdown]
# 2. Add a mathematical formula to add 15 and 22 in the cell below

# %%
15+22
# Out:
# 37

# %% [markdown]
# ## **Part 3: Print value of variables**

# %% [markdown]
# ### **🔧 Try It Yourself - Part 3**

# %% [markdown]
# 3. Create a variable called "x" with the value "Hello World".  Print the value of the variable

# %%
x = "Hello World"
print(x)
# Out:
# Hello World

# %% [markdown]
# ## Export Your Notebook to Submit in Canvas
# - In the top menu, go to File > Download, click "Download .ipynb". Save the file locally with the name *lab_01_LastnameFirstname.ipynb*
# - In the left side menu, click the Folder icon, then click the "Upload to Session Storage" icon, and select the above saved file to add it to Colab's temporary Virtual Machine (VM) that allows us to work on our files in Colab.
# - Convert the file to HTML using the code below.  You may be asked to approve access to the files
# - Find the output file under Files in the left side menu
# - Download your HTML file (*lab_01_LastnameFirstname.html*) as your completed lab, to be uploaded to Canvas

# %%
# !jupyter nbconvert --to html "lab_01_Linlin Gong.ipynb"
# Out:
# [NbConvertApp] Converting notebook lab_01_Linlin Gong.ipynb to html
# [NbConvertApp] Writing 291018 bytes to lab_01_Linlin Gong.html

# %% [markdown]
# ## Submit your Lab
#
# - Make sure that all of your output is shown.  If you get the “unable to render code block” error, try refreshing the cache or downloading raw data to manually upload into Colab as a workaround.
# - Upload your HTML file to Canvas
# - Optionally, save your file in your own GitHub account for future use
