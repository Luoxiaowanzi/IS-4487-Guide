# %% [markdown]
# > ### Note on Labs and Assigments:
# >
# > 🔧 Look for the **wrench emoji** 🔧 — it highlights where you're expected to take action!
# >
# > These sections are graded and are not optional.
# >

# %% [markdown]
# # **IS 4487 LAB 3 - VISUALIZATION INTRO**
#
# ## Outline
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# <a href="https://colab.research.google.com/github/vandanara/UofUtah_IS4487/blob/main/Labs/lab_03_visualization_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# If you have any questions about Colab, you can read more here:  https://research.google.com/colaboratory/faq.html

# %% [markdown]
# ## **Business Context: Motor Trends Car Road Tests**
#
# As in the previous lab, you will work with the mtcars dataset, a classic collection of data about cars from the 1970s. It includes features such as miles per gallon (mpg), horsepower, weight, number of cylinders, and transmission type. Although the dataset is relatively small, it contains enough variety to explore meaningful relationships—like how a car’s weight impacts fuel efficiency or how horsepower relates to performance. Because it is clean, well-structured, and widely used in data science education, mtcars is an excellent starting point for learning Python tools like pandas, data visualization, and basic statistical analysis without the added complexity of messy real-world data.

# %% [markdown]
# ## **Part 1: Load Libraries**
#
# In this assignment we will be using **Pandas**
#
# We can pull sample data from **statsmodels.api**

# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ## **Part 2: Getting data into Pandas**
#
# In this case we will load the MTCARS data from the statsmodels.org library

# %%
mtcars = sm.datasets.get_rdataset("mtcars", "datasets", cache=True).data
df = pd.DataFrame(mtcars)
df['carmodel'] = df.index
print(df)
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# rownames
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %% [markdown]
# ## **Part 3: Preview Data**
#
# Use the following data dictionary to understand the attributes available
#
# |Attribute | Description |
# |---------|--------------|
# |	mpg	|Miles/(US) gallon|
# |	cyl|	Number of cylinders|
# |	disp|	Displacement (cu.in.)|
# |hp|	Gross horsepower|
# |drat|	Rear axle ratio|
# |wt|	Weight (1000 lbs)|
# |qsec|	1/4 mile time|
# |vs|	Engine (0 = V-shaped, 1 = straight)|
# |am|	Transmission (0 = automatic, 1 = manual)|
# |gear|	Number of forward gears|

# %%
#look at data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mpg       32 non-null     float64
#  1   cyl       32 non-null     int64
#  2   disp      32 non-null     float64
#  3   hp        32 non-null     int64
#  4   drat      32 non-null     float64
#  5   wt        32 non-null     float64
#  6   qsec      32 non-null     float64
#  7   vs        32 non-null     int64
#  8   am        32 non-null     int64
#  9   gear      32 non-null     int64
#  10  carb      32 non-null     int64
#  11  carmodel  32 non-null     object
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.2+ KB

# %%
#look at top rows
df.head(10)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# rownames
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant            18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360         14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D          24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230           22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280           19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#                    carb           carmodel
# rownames
# Mazda RX4             4          Mazda RX4
# ...

# %%
#get a summary of the dataset
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## **Part 4: Create basic charts**
#
# Pandas makes it easy to create data visualizations directly from a DataFrame using built-in charting functions. With simple commands like `df.plot()`, you can quickly generate line charts, bar graphs, histograms, and more without needing a lot of extra code. These visualizations help you see patterns, trends, and relationships in your data that might not be obvious from raw numbers alone. By learning how to use pandas’ plotting tools, you can turn your analysis into clear, visual insights that are easier to understand and communicate.
#
# Below are examples of the following chart types:
#
# - Line chart
# - Bar chart
# - Histogram
# - Box plot
# - Scatter plot

# %%
#Line chart
df.plot(x='carmodel', y='mpg', kind='line', title="MPG by Car")
# Out:
# <Axes: title={'center': 'MPG by Car'}, xlabel='carmodel'>

# %%
#Bar chart
df.plot(x='carmodel', y='mpg', kind='bar', title="MPG by Car")
# Out:
# <Axes: title={'center': 'MPG by Car'}, xlabel='carmodel'>

# %%
#Histogram
df['mpg'].plot(kind='hist', bins=10, title="MPG Distribution")
# Out:
# <Axes: title={'center': 'MPG Distribution'}, ylabel='Frequency'>

# %%
#Boxplot
df['mpg'].plot(kind='box', title = 'Miles Per Gallon')
# Out:
# <Axes: title={'center': 'Miles Per Gallon'}>

# %%
#Scatter plot
df.plot.scatter(x='mpg',y='hp',c='wt')
# Out:
# <Axes: xlabel='mpg', ylabel='hp'>

# %% [markdown]
# ## **🔧 Try It Yourself: Part 5 - Create Additional Charts**
#
# You are welcome to import additional libraries for these tasks.

# %% [markdown]
# 4.1. Create a pie chart showing the count of cars by transmission type.  Display labels showing the percentage of each transmission type.

# %%
# 🔧 4.1. Pie chart

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each transmission type
transmission_counts = df['am'].value_counts()

# Map 0 to 'Automatic' and 1 to 'Manual' for better labels
transmission_labels = transmission_counts.index.map({0: 'Automatic', 1: 'Manual'})

# Create the pie chart
fig = plt.figure(figsize=(8, 8))
plt.pie(transmission_counts, labels=transmission_labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Distribution of Transmission Types')
plt.ylabel('') # Hide the default 'am' label on the y-axis
plt.show()

# %% [markdown]
# 4.2. Create a bar chart of cars and HP, with different colors for each car model

# %%
# 🔧 4.2. Bar chart

# %%
import seaborn as sns

# Create a bar chart of cars and HP, with different colors for each car model
# Using carmodel as a column by resetting index for plotting or directly accessing df.index

# Sort by HP for better visualization
df_sorted_hp = df.sort_values('hp', ascending=False)

fig = plt.figure(figsize=(12, 8))
sns.barplot(x=df_sorted_hp.index, y='hp', data=df_sorted_hp, hue=df_sorted_hp.index, dodge=False, palette='viridis')
plt.title('Horsepower by Car Model')
plt.xlabel('Car Model')
plt.ylabel('Horsepower (hp)')
plt.xticks(rotation=90) # Rotate labels for readability
plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.legend().remove() # Remove the legend as hue is already specified by labels
plt.show()
# Out:
# /tmp/ipykernel_3432/2273549177.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend().remove() # Remove the legend as hue is already specified by labels

# %% [markdown]
# 4.3. Create a scatter plot of wt (weight) vs. mpg.

# %%
# 🔧 4.3. Scatter plot

# %%
# Scatter plot of wt (weight) vs. mpg

fig = plt.figure(figsize=(10, 6))
sns.scatterplot(x='wt', y='mpg', data=df, hue='cyl', size='hp', sizes=(50, 500), palette='coolwarm', alpha=0.7)
plt.title('Weight vs. MPG (colored by Cylinders, sized by HP)')
plt.xlabel('Weight (1000 lbs)')
plt.ylabel('Miles Per Gallon (mpg)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# 4.4.  Create a bar chart showing the average mpg for each cyl.

# %%
# 🔧 4.4. Bar chart

# %%
# Calculate the average mpg for each cyl
avg_mpg_by_cyl = df.groupby('cyl')['mpg'].mean().reset_index()

# Create a bar chart
fig = plt.figure(figsize=(8, 6))
sns.barplot(x='cyl', y='mpg', data=avg_mpg_by_cyl, palette='plasma')
plt.title('Average MPG by Number of Cylinders')
plt.xlabel('Number of Cylinders')
plt.ylabel('Average Miles Per Gallon (mpg)')
plt.show()
# Out:
# /tmp/ipykernel_3432/1326837659.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='cyl', y='mpg', data=avg_mpg_by_cyl, palette='plasma')

# %% [markdown]
# 4.5. Plot a histogram of the weight column.

# %%
# 🔧 4.5. Histogram

# %%
# Plot a histogram of the weight column
fig = plt.figure(figsize=(8, 6))
sns.histplot(df['wt'], bins=8, kde=True, color='purple')
plt.title('Distribution of Car Weight')
plt.xlabel('Weight (1000 lbs)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **Part 6: Reflection 🔧**
# 🔧 Answer in approx 100 words (or less) per question
#
#   6.1. Referring to the first graph you made (i.e. the pie chart) which transmission type has the larger frequency? (i.e. which transmission type has the largest slice of the pie?)
#
#   6.2. Referring to the last graph you made (i.e. the histogram) which weight is the most frequent?
#
#   6.3. By looking at the charts above, you can see which variables have a relationship with MPG.  If you were to give advice to a manufacturer on how to optimize MPG, what changes to a car would you suggest, based on the charts you have created?
#
#
# ### ✍️ Your Response: 🔧
# 6.1. Automatic transmission has the larger frequency.
#
# 6.2. The most frequent car weight is between 3,000 and 3,500 pounds.
#
# 6.3. I suggest making cars lighter and using fewer cylinders and less horsepower. The charts show that these cars usually use less gas.

# %% [markdown]
# ## Export Your Notebook to Submit in Canvas
# Please note that this current notebook that you are working on is loaded only into your browser for editing and execution. In order to run the below nbcovert command, the file needs to be loaded into Colab's Virtual Machine (VM) for your session (also temporary and wiped when you end this Colab session).
#
# - **1. Download to local machine**\
# In the top menu, go to *File > Download > Download .ipynb*. (DO NOT download *.py)
#
# - **2. Upload to Colab session's virtual machine VM**\
# In the left side menu, click the Folders icon, then click the *Upload to Session Storage* icon at the top of the window that opens on the left side. Select the above saved file on your local machine to upload it to Colab's temporary (VM) storage. This file will be saved in /content/ (or ensure you save it to /content/) folder on the VM.
#
# - **3. Rename and Convert the file to HTML**\
# You will need to rename the file by right clicking it. Add your last and firstname. Run the cell below but ***edit it first*** to match your filename with *yourLastnameFirstname*.  You may be asked to approve access to the files. If done correctly, it will add an html file with the same filename in the VM storage. You can see it in the VM storage window on the left.
#
# - **4. Download the HTML file**\
# Download your HTML file (***lab_0x_LastnameFirstname.html***) as your completed lab. Please ensure that you change the name to reflect YOUR last name and first name. Then upload to Canvas.

# %%
# !jupyter nbconvert --to html "lab_03_Gong Linlin.ipynb"
# Out:
# [NbConvertApp] Converting notebook lab_03_Gong Linlin.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 10 image(s).
# [NbConvertApp] Writing 783609 bytes to lab_03_Gong Linlin.html

# %% [markdown]
# ## Submit your assignment
#
# - Make sure that all of your output is shown.
# When there are multiple subtasks, good ideas to write code for each in its own cell.
# - If you use AI, it is your responsibility to clean up the AI code. Only keep the outputs relevant to each subtask or task question.
# - Upload your HTML file to Canvas. make sure that your lastnamefirstname are part of the filename as requested above
# - Optionally, save your file in your own GitHub account for future use
